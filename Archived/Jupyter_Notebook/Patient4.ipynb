# %%
from pathlib import Path

import scanpy as sc
import spatialdata as sd
import spatialdata_plot
import squidpy as sq
from spatialdata import SpatialData, read_zarr
import pandas as pd
# Out:
# C:\Users\lyuan13\.conda\envs\spatial\lib\site-packages\numba\core\decorators.py:246: RuntimeWarning: nopython is set for njit and is ignored
#   warnings.warn('nopython is set for njit and is ignored', RuntimeWarning)

# %%
adata = sc.read_h5ad("/Users/lyuan13/Downloads/Xenium/adata_clean_P4_resection.h5ad")
print(adata)
# Out:
# AnnData object with n_obs × n_vars = 108437 × 366
#     obs: 'x_centroid', 'y_centroid', 'transcript_counts', 'control_probe_counts', 'genomic_control_counts', 'control_codeword_counts', 'unassigned_codeword_counts', 'deprecated_codeword_counts', 'total_counts', 'cell_area', 'nucleus_area', 'nucleus_count', 'segmentation_method', 'batch', 'n_genes_by_counts', 'log1p_n_genes_by_counts', 'log1p_total_counts', 'pct_counts_in_top_50_genes', 'pct_counts_in_top_100_genes', 'pct_counts_in_top_200_genes', 'pct_counts_in_top_300_genes', 'n_counts', 'T cell', 'Oligodendrocytic', 'Cancer', 'Neuronal', 'Myleoid', 'Vascular', 'annotation', 'doublet'
#     var: 'n_cells_by_counts', 'mean_counts', 'log1p_mean_counts', 'pct_dropout_by_counts', 'total_counts', 'log1p_total_counts', 'n_cells', 'mean', 'std'
#     uns: 'annotation_colors', 'batch_colors', 'dendrogram_annotation', 'doublet_colors', 'neighbors', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap', 'spatial'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\.conda\envs\spatial\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'uns'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [9], in <cell line: 1>()
# ----> 1 adata['uns'].head()
#
# File ~\.conda\envs\spatial\lib\site-packages\anndata\_core\anndata.py:1021, in AnnData.__getitem__(self, index)
#    1019 def __getitem__(self, index: Index) -> AnnData:
#    1020     """Returns a sliced view of the object."""
# -> 1021     oidx, vidx = self._normalize_indices(index)
#    1022     return AnnData(self, oidx=oidx, vidx=vidx, asview=True)
#
# File ~\.conda\envs\spatial\lib\site-packages\anndata\_core\anndata.py:1002, in AnnData._normalize_indices(self, index)
#    1001 def _normalize_indices(self, index: Index | None) -> tuple[slice, slice]:
# -> 1002     return _normalize_indices(index, self.obs_names, self.var_names)
#
# File ~\.conda\envs\spatial\lib\site-packages\anndata\_core\index.py:38, in _normalize_indices(index, names0, names1)
#      36         index = index[0].values, index[1]
#      37 ax0, ax1 = unpack_index(index)
# ---> 38 ax0 = _normalize_index(ax0, names0)
#      39 ax1 = _normalize_index(ax1, names1)
#      40 return ax0, ax1
#
# File ~\.conda\envs\spatial\lib\site-packages\anndata\_core\index.py:76, in _normalize_index(indexer, index)
#      74     return indexer
#      75 elif isinstance(indexer, str):
# ---> 76     return index.get_loc(indexer)  # int
#      77 elif isinstance(indexer, (Sequence, np.ndarray, pd.Index, spmatrix, np.matrix)):
#      78     if hasattr(indexer, "shape") and (
#      79         (indexer.shape == (index.shape[0], 1))
#      80         or (indexer.shape == (1, index.shape[0]))
#      81     ):
#
# File ~\.conda\envs\spatial\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'uns'

# %%
sdata = sd.models.spatialdata_from_anndata(adata)
print(sdata)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 sdata = sd.models.spatialdata_from_anndata(adata)
#       2 print(sdata)
#
# AttributeError: module 'spatialdata.models' has no attribute 'spatialdata_from_anndata'
